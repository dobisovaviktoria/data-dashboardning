# %%
import ConnectionConfig as cc
from delta import DeltaTable
from datetime import datetime

# %%
cc.setupEnvironment()
spark = cc.startLocalCluster("dimUser")
spark.getActiveSession()
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://10.140.33.222:4043">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.5.2</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>dimUser</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
run_timestamp =datetime.now()

# %%
dt_dimUserCurrent = DeltaTable.forPath(spark,"./spark-warehouse/user_dim_current")

# %%
dt_dimUserCurrent.toDF().createOrReplaceTempView("user_dim_current")

# %%
spark.sql("select * from user_dim_current").show()
# Out:
# +------+-------------------+--------------------+--------------------+--------+-------+--------------------+------------+--------------------+-------------------+-------------------+--------------------+-------+
# |userid|               name|               email|              street|  number|zipcode|                city|country_code|             user_sk|          scd_start|            scd_end|                 md5|current|
# +------+-------------------+--------------------+--------------------+--------+-------+--------------------+------------+--------------------+-------------------+-------------------+--------------------+-------+
# | 30001|   de Ruijter Maria|Maria.de.Ruijter@...|            Kallodam| 50 0802|   9120|Beveren-Waas/Haas...|          BE|e408b9fe-27d8-4ff...|1990-01-01 00:00:00|2100-12-12 00:00:00|ca6acc87cdd2dbf67...|   true|
# | 30002|    Dijkstra Myrthe|Myrthe.Dijkstra@t...|    Lange Repeldreef|    539 |   2970|s Gravenwezel/Sch...|          BE|9ef0cf0d-b32e-406...|1990-01-01 00:00:00|2100-12-12 00:00:00|879e5d13c7e2ec43f...|   true|
# | 30003| van der Laan Daisy|Daisy.van.der.Laa...|           Tolstraat|580 0502|   2000|           Antwerpen|          BE|2db2745f-e4f0-4cd...|1990-01-01 00:00:00|2100-12-12 00:00:00|976cd4ea7a8fd2580...|   true|
# | 30004|   van der Wal Anne|Anne.van.der.Wal@...|         Zijdestraat|152 0805|   2930|          Brasschaat|          BE|c820f2c9-c956-4bb...|1990-01-01 00:00:00|2100-12-12 00:00:00|3bab3c3aa35831f15...|   true|
# | 30005|      Jonker Dennis|Dennis.Jonker@tel...|           Speltlaan|227 0904|   2520|Broechem/Emblem/O...|          BE|7b4130d1-ab5a-404...|1990-01-01 00:00:00|2100-12-12 00:00:00|d17a5089ad8fdbb6b...|   true|
# | 30006|        Vis Maartje|Maartje.Vis@gmail...|   Oostmalsesteenweg|    165 |   2520|Broechem/Emblem/O...|          BE|28e7aa5a-f34c-449...|1990-01-01 00:00:00|2100-12-12 00:00:00|b794a61013a504fbc...|   true|
# | 30007|      van Duijn Eva|Eva.van.Duijn@gma...|         Bloemenveld|    113 |   2610| Wilrijk (Antwerpen)|          BE|b2be4f3a-18ec-4a8...|1990-01-01 00:00:00|2100-12-12 00:00:00|d65234c6e7deca332...|   true|
# | 30008|       de Jong Erik|Erik.de.Jong@tele...|       Gemeenteplein|    177 |   2550|    Kontich/Waarloos|          BE|04136c21-2fc6-451...|1990-01-01 00:00:00|2100-12-12 00:00:00|bad6049b48fbe8b6b...|   true|
# | 30009|       Visser Nicky|Nicky.Visser@gmai...|     Bondgenotenlaan|     56 |   2950|    Kapellen (Antw.)|          BE|d01d6c88-c4cc-44f...|1990-01-01 00:00:00|2100-12-12 00:00:00|ef1da533f3822c26c...|   true|
------+--------------------+--------------------+--------+-------+--------------------+------------+--------------------+-------------------+-------------------+--------------------+-------+
# only showing top 20 rows

# %%
cc.set_connectionProfile("veloDB")

df_operational_users_new = spark.read \
    .format("jdbc") \
    .option("driver", cc.get_Property("driver")) \
    .option("url", cc.create_jdbc()) \
    .option("dbtable", "velo_users") \
    .option("user", cc.get_Property("username")) \
    .option("password", cc.get_Property("password")) \
    .option("partitionColumn", "userid") \
    .option("numPartitions", 4) \
    .option("lowerBound", 1) \
    .option("upperBound", 60000) \
    .load()

df_operational_users_new.createOrReplaceTempView("operational_users")

df_operational_users_new.show(5)
# Out:
# +------+-----------------+--------------------+--------------------+------+-------+-------------------+------------+
# |userid|             name|               email|              street|number|zipcode|               city|country_code|
# +------+-----------------+--------------------+--------------------+------+-------+-------------------+------------+
# |     1|      Bouman Lars|Lars.Bouman@gmail...|         Somméstraat|  156 |   2060|          Antwerpen|          BE|
# |     2|van der Zee Julia|Julia.van.der.Zee...|          Europalaan|   43 |   2610|Wilrijk (Antwerpen)|          BE|
# |     3|  de Boer Ricardo|Ricardo.de.Boer@g...|   Maria Clarastraat|   80 |   2160|          Wommelgem|          BE|
# |     4|   Willems Angela|Angela.Willems@te...|Graaf Joseph de P...|   15 |   2900|            Schoten|          BE|
# |     5| Heijnen Patricia|Patricia.Heijnen@...|          Meylstraat|  111 |   2540|               Hove|          BE|
# +------+-----------------+--------------------+--------------------+------+-------+-------------------+------------+
# only showing top 5 rows

# %%
df_user_dim_new = spark.sql( """
    SELECT uuid() as source_user_sk,
           userid as source_user_id,
           name as source_user_name,
           email as source_user_email,
           street as source_street,
           number as source_number,
           zipcode as source_zipcode,  
           city as source_city,
           country_code as source_country_code,
           md5(concat(name, email)) as source_md5
    FROM operational_users
""")

df_user_dim_new.createOrReplaceTempView("user_dim_new")

# Debugging
df_user_dim_new.show()
# Out:
# +--------------------+--------------+--------------------+--------------------+--------------------+-------------+--------------+--------------------+-------------------+--------------------+
# |      source_user_sk|source_user_id|    source_user_name|   source_user_email|       source_street|source_number|source_zipcode|         source_city|source_country_code|          source_md5|
# +--------------------+--------------+--------------------+--------------------+--------------------+-------------+--------------+--------------------+-------------------+--------------------+
# |83064122-532d-454...|             1|         Bouman Lars|Lars.Bouman@gmail...|         Somméstraat|         156 |          2060|           Antwerpen|                 BE|26b6b7d4dd32d5cd0...|
# |e51501bd-fe77-430...|             2|   van der Zee Julia|Julia.van.der.Zee...|          Europalaan|          43 |          2610| Wilrijk (Antwerpen)|                 BE|4e2e54541cbdd9474...|
# |60581d68-a8f6-40a...|             3|     de Boer Ricardo|Ricardo.de.Boer@g...|   Maria Clarastraat|          80 |          2160|           Wommelgem|                 BE|12a0a84de074b278c...|
# |10a5c937-2e8a-44c...|             4|      Willems Angela|Angela.Willems@te...|Graaf Joseph de P...|          15 |          2900|             Schoten|                 BE|a00e8c8bfa8b96144...|
# |62eb32c7-eb2c-449...|             5|    Heijnen Patricia|Patricia.Heijnen@...|          Meylstraat|         111 |          2540|                Hove|                 BE|70b47ffab5656b980...|
# |d4a5cd83-759b-491...|             6|      Driessen Anouk|Anouk.Driessen@sc...|   Jan Ockegemstraat|     168 0107|          2650|              Edegem|                 BE|2a8815e04703df7d6...|
# |cb8c36f5-067e-4ed...|             7|      Dijkstra Frank|Frank.Dijkstra@sc...|        Klamperdreef|         154 |          2900|             Schoten|                 BE|9a7a3e8620934605e...|
# |761a62da-5ecb-4d8...|             8|  den Hartog Suzanne|Suzanne.den.Harto...|      Kolibriestraat|     138 0608|          2170| Merksem (Antwerpen)|                 BE|b2094613ff20efde3...|
# |56f48b0d-991e-467...|             9|            Smit Tim|  Tim.Smit@gmail.com|       Bikschotelaan|          60 |          2600| Berchem (Antwerpen)|                 BE|f3a1bd73f633e6ce0...|
# |e154de73-e974-466...|            10|van der Steen Carmen|Carmen.van.der.St...|          Benzineweg|         137 |          2020|           Antwerpen|                 BE|5b1ded545166cd11b...|
# |95cabc08-f205-4f6...|            11| de Ruijter Daniëlle|Daniëlle.de.Ruijt...|      Leo Metsstraat|      21 0905|          2070|  Burcht/Zwijndrecht|                 BE|84d4543a0c9b2a6c4...|
# |c8f6371c-1cb8-438...|            12|        Simons Thijs|Thijs.Simons@outl...|         Bergenhoeve|      81 0302|          2040|Antwerpen/Berendr...|                 BE|e653e271b6f19a145...|
# |57f8ab58-cd67-4c4...|            13|          Groen Rens|Rens.Groen@outloo...|  Trompetvogelstraat|           1 |          2170| Merksem (Antwerpen)|                 BE|6399612efba63d0db...|
# |361c809a-d08d-4a9...|            14|   van der Veer Romy|Romy.van.der.Veer...|Prosper De Vochtlaan|         177 |          2550|    Kontich/Waarloos|                 BE|c3a3f47dce644b62e...|
# |218f9408-0dcc-41a...|            15|           Hoek Emma|Emma.Hoek@telenet.be|    John Kennedylaan|       9 0801|          2520|Broechem/Emblem/O...|                 BE|76309219557e4242b...|
# |cb5f2729-be68-4f3...|            16|     Stevens Suzanne|Suzanne.Stevens@t...|              Wijk 2|      19 0802|          2531|              Vremde|                 BE|6176da5b8542374fb...|
# |9b19146b-690f-48a...|            17|van den Bosch Rutger|Rutger.van.den.Bo...|       Schoggestraat|          73 |          2100|  Deurne (Antwerpen)|                 BE|5b428e8eded8fe641...|
# |7b52ed02-00fa-439...|            18|      Veldman Angela|Angela.Veldman@gm...|Emiel Van Hemeldo...|          93 |          2540|                Hove|                 BE|73e16e6167ddbb030...|
# |dea6e843-d6ac-4ee...|            19|     Bakker Daniëlle|Daniëlle.Bakker@s...|            Fortbaan|          88 |          2160|           Wommelgem|                 BE|8b071d2ae292491c4...|
# |8c920923-20d1-4fd...|            20|      Vink Elisabeth|Elisabeth.Vink@gm...|  Joseph Wateletlaan|     100 0403|          2160|           Wommelgem|                 BE|56dad554919981faa...|
# +--------------------+--------------+--------------------+--------------------+--------------------+-------------+--------------+--------------------+-------------------+--------------------+
# only showing top 20 rows

# %%
detectedChanges = spark.sql("""
    select * from user_dim_new source \
    left outer join user_dim_current dwh on dwh.userid == source.source_user_id and dwh.current == true \
    where dwh.userid is null or dwh.md5 <> source.source_md5
""")

detectedChanges.createOrReplaceTempView("detectedChanges")
detectedChanges.show()
# Out:
# +--------------+--------------+----------------+-----------------+-------------+-------------+--------------+-----------+-------------------+----------+------+----+-----+------+------+-------+----+------------+-------+---------+-------+---+-------+
# |source_user_sk|source_user_id|source_user_name|source_user_email|source_street|source_number|source_zipcode|source_city|source_country_code|source_md5|userid|name|email|street|number|zipcode|city|country_code|user_sk|scd_start|scd_end|md5|current|
# +--------------+--------------+----------------+-----------------+-------------+-------------+--------------+-----------+-------------------+----------+------+----+-----+------+------+-------+----+------------+-------+---------+-------+---+-------+
# +--------------+--------------+----------------+-----------------+-------------+-------------+--------------+-----------+-------------------+----------+------+----+-----+------+------+-------+----+------------+-------+---------+-------+---+-------+

# %%
df_user_upserts = spark.sql(f"""
    select source_user_sk as user_sk, \
    source_user_id as userid, \
    source_user_name as name, \
    source_user_email as email, \
    source_street as street, \
    source_number as number, \
    source_zipcode as zipcode, \
    source_city as city, \
    source_country_code as country_code, \
    to_timestamp('{run_timestamp}') as scd_start, \
    to_timestamp('2100-12-12', 'yyyy-MM-dd') as scd_end, \
    source_md5 as md5, \
    true as current \
    from detectedChanges \
    union \
    select user_sk, \
    userid, \
    name, \
    email, \
    street,\
    number,\
    zipcode,\
    city,\
    country_code,\
    scd_start,\
    to_timestamp('{run_timestamp}') as scd_end, \
    md5, \
    false \
    from detectedChanges \
    where current is not null
""")

df_user_upserts.createOrReplaceTempView("upserts")
df_user_upserts.show()
# Out:
# +-------+------+----+-----+------+------+-------+----+------------+---------+-------+---+-------+
# |user_sk|userid|name|email|street|number|zipcode|city|country_code|scd_start|scd_end|md5|current|
# +-------+------+----+-----+------+------+-------+----+------------+---------+-------+---+-------+
# +-------+------+----+-----+------+------+-------+----+------------+---------+-------+---+-------+

# %%
# DEBUG CODE TO SHOW CONTENT OF UPSERTS
spark.sql("select * from upserts").show()
# Out:
# +-------+------+----+-----+------+------+-------+----+------------+---------+-------+---+-------+
# |user_sk|userid|name|email|street|number|zipcode|city|country_code|scd_start|scd_end|md5|current|
# +-------+------+----+-----+------+------+-------+----+------------+---------+-------+---+-------+
# +-------+------+----+-----+------+------+-------+----+------------+---------+-------+---+-------+

# %%
spark.sql("""
    MERGE INTO user_dim_current AS target
    USING upserts AS source
    ON target.userid = source.userid AND source.current = false and target.current = true

    WHEN MATCHED THEN UPDATE SET scd_end = source.scd_end, current = source.current
    WHEN NOT MATCHED THEN INSERT (user_sk, userid, name, email, street, number, zipcode, city, country_code, scd_start, scd_end, md5, current) values (source.user_sk, source.userid, source.name, source.email, source.street, source.number, source.zipcode, source.city, source.country_code, source.scd_start, source.scd_end, source.md5, source.current)
""")
# Out:
# DataFrame[num_affected_rows: bigint, num_updated_rows: bigint, num_deleted_rows: bigint, num_inserted_rows: bigint]

# %%
dt_dimUserCurrent.toDF().sort("name", "scd_start").show(100)
# Out:
# +------+---------------+--------------------+--------------------+--------+-------+--------------------+------------+--------------------+-------------------+-------------------+--------------------+-------+
# |userid|           name|               email|              street|  number|zipcode|                city|country_code|             user_sk|          scd_start|            scd_end|                 md5|current|
# +------+---------------+--------------------+--------------------+--------+-------+--------------------+------------+--------------------+-------------------+-------------------+--------------------+-------+
# | 32311|Aarts Alexander|Alexander.Aarts@o...|      Noeversebosweg|757 0607|   2627|             Schelle|          BE|3f8bd3bc-93ce-4ea...|1990-01-01 00:00:00|2100-12-12 00:00:00|74b85cd21b356ee74...|   true|
# | 29923|Aarts Alexander|Alexander.Aarts@o...|Camille Huysmanss...|    453 |   9150|Bazel/Kruibeke/Ru...|          BE|4f865a3b-bc4d-4e9...|1990-01-01 00:00:00|2100-12-12 00:00:00|74b85cd21b356ee74...|   true|
