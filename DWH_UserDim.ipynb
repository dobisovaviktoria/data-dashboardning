# %%
import ConnectionConfig as cc
from delta import DeltaTable
from datetime import datetime

# %%
cc.setupEnvironment()
spark = cc.startLocalCluster("dimUser")
spark.getActiveSession()
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://192.168.0.199:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.5.2</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>dimUser</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
run_timestamp =datetime.now()

# %%
dt_dimUserCurrent = DeltaTable.forPath(spark,"file:/D:/KdG/Year%202/Sem2/DataAI_Sem_2/sparkdelta/spark-warehouse/user_dim_current")

# %%
dt_dimUserCurrent.toDF().createOrReplaceTempView("user_dim_current")

# %%
cc.set_connectionProfile("veloDB")

df_operational_users = spark.read \
    .format("jdbc") \
    .option("driver", cc.get_Property("driver")) \
    .option("url", cc.create_jdbc()) \
    .option("dbtable", "velo_users") \
    .option("user", cc.get_Property("username")) \
    .option("password", cc.get_Property("password")) \
    .load()

df_operational_users.createOrReplaceTempView("operational_users")

# %%
df_user_dim_new = spark.sql( """
    SELECT uuid() as source_userSK,  
           userid as source_user_id,  
           name as source_name,  
           zipcode as source_zipcode,  
           city as source_city,  
           md5(concat(name, zipcode, city)) as source_md5  
    FROM operational_users
""")

df_user_dim_new.createOrReplaceTempView("user_dim_new")

# Debugging
df_user_dim_new.show()
# Out:
# +--------------------+--------------+--------------------+--------------+--------------------+--------------------+
# |       source_userSK|source_user_id|         source_name|source_zipcode|         source_city|          source_md5|
# +--------------------+--------------+--------------------+--------------+--------------------+--------------------+
# |7f439ee8-2d59-4b0...|             1|         Bouman Lars|          2060|           Antwerpen|5326bbf5b41d3f9dc...|
# |7f5c4d67-3ed8-4b6...|             2|   van der Zee Julia|          2610| Wilrijk (Antwerpen)|1491518a1ac33937d...|
# |38b42894-67e2-45d...|             3|     de Boer Ricardo|          2160|           Wommelgem|2b6e4d3ed6e925255...|
# |3adce29c-af93-4e1...|             4|      Willems Angela|          2900|             Schoten|49a5ddc033ae5f2b7...|
# |337f02aa-c68b-427...|             5|    Heijnen Patricia|          2540|                Hove|c87269ed29b9096f7...|
# |8211f694-5418-46f...|             6|      Driessen Anouk|          2650|              Edegem|ae81e29e2fb7849e7...|
# |5561cfeb-4632-427...|             7|      Dijkstra Frank|          2900|             Schoten|e775529a4683e57bb...|
# |db417dd2-c129-430...|             8|  den Hartog Suzanne|          2170| Merksem (Antwerpen)|064992b16738f0561...|
# |8998a5fd-c1ee-438...|             9|            Smit Tim|          2600| Berchem (Antwerpen)|6a3967c7c70d07c17...|
# |65393e37-3a75-4e3...|            10|van der Steen Carmen|          2020|           Antwerpen|08edabd4bcab22ee8...|
# |6addc288-163d-43a...|            11| de Ruijter Daniëlle|          2070|  Burcht/Zwijndrecht|56b0d91f98d932fcd...|
# |a4df6c39-775e-4ce...|            12|        Simons Thijs|          2040|Antwerpen/Berendr...|e05f994d152f2fb2b...|
# |35752970-48a1-451...|            13|          Groen Rens|          2170| Merksem (Antwerpen)|7618cf4e6b3622250...|
# |9ef51d52-9174-492...|            14|   van der Veer Romy|          2550|    Kontich/Waarloos|45ed4b05e4166a6ad...|
# |a27627aa-45e0-4ad...|            15|           Hoek Emma|          2520|Broechem/Emblem/O...|4724a5cab65d74945...|
# |b6af51c4-6de8-467...|            16|     Stevens Suzanne|          2531|              Vremde|ba2010bb5c7947a1c...|
# |5a8a7c3d-20e4-441...|            17|van den Bosch Rutger|          2100|  Deurne (Antwerpen)|7ca495285fda57f47...|
# |df7dfbfc-e709-405...|            18|      Veldman Angela|          2540|                Hove|381655805c09b7298...|
# |44f6e590-bd4e-497...|            19|     Bakker Daniëlle|          2160|           Wommelgem|9d9ec1e6af65311f5...|
# |01d7f230-7492-472...|            20|      Vink Elisabeth|          2160|           Wommelgem|570f58f530cacfae1...|
# +--------------------+--------------+--------------------+--------------+--------------------+--------------------+
# only showing top 20 rows

# %%
detectedChanges = spark.sql("""
    SELECT 
        source.source_userSK,  
        source.source_user_id,  
        source.source_name,  
        source.source_zipcode,  
        source.source_city,  
        source.source_md5,  
        dwh.source_user_id AS dwh_user_id,  -- Rename to avoid duplicate column names
        dwh.source_md5 AS dwh_md5 
    FROM user_dim_new source  
    LEFT OUTER JOIN user_dim_current dwh  
    ON dwh.source_user_id = source.source_user_id AND dwh.current = true  
    WHERE dwh.source_user_id IS NULL OR dwh.source_md5 <> source.source_md5
""")

detectedChanges.createOrReplaceTempView("detectedChanges")

# %%
df_user_upserts = spark.sql(f"""
    SELECT 
        source_userSK as userSK,
        source_user_id as user_id,
        source_name as name,
        source_city as city,
        source_zipcode as zipcode,
        to_timestamp('{run_timestamp}') as scd_start,
        to_timestamp('2100-12-12', 'yyyy-MM-dd') as scd_end,
        source_md5 as md5,
        true as current
    FROM detectedChanges  
    UNION
    SELECT  
        userSK,
        source_user_id,
        source_name,
        source_city,
        source_zipcode,
        scd_start,
        to_timestamp('{run_timestamp}') as scd_end,
        source_md5, 
        false 
    FROM user_dim_current  --  Use user_dim_current instead of detectedChanges
    WHERE source_user_id IN (SELECT source_user_id FROM detectedChanges)  
    AND current = true  --  Ensure we only expire current records
""")

# %%
df_new_upserts.createOrReplaceTempView("upserts")

# %%
# DEBUG CODE TO SHOW CONTENT OF UPSERTS
spark.sql("select * from upserts").show()
# Out:
# +------+------+----+----+-------+---------+-------+----------+-------+
# |userSK|userID|name|city|zipcode|scd_start|scd_end|source_md5|current|
# +------+------+----+----+-------+---------+-------+----------+-------+
# +------+------+----+----+-------+---------+-------+----------+-------+

# %%
spark.sql("""
    MERGE INTO user_dim_current AS target
    USING upserts AS source
    ON target.source_user_id = source.userID AND target.current = TRUE

    WHEN MATCHED AND target.source_md5 <> source.source_md5 THEN 
        UPDATE SET 
            target.scd_end = source.scd_start, 
            target.current = FALSE

    WHEN NOT MATCHED THEN 
        INSERT (userSK, source_user_id, source_name, source_city, source_zipcode, scd_start, scd_end, source_md5, current) 
        VALUES (source.userSK, source.userID, source.name, source.city, source.zipcode, source.scd_start, source.scd_end, source.source_md5, source.current);
""")
# Out:
# DataFrame[num_affected_rows: bigint, num_updated_rows: bigint, num_deleted_rows: bigint, num_inserted_rows: bigint]

# %%
dt_dimUserCurrent.toDF().sort("source_user_id", "scd_start").show(100)
# Out:
# +--------------------+--------------+--------------------+--------------------+--------------+-------------------+-------------------+--------------------+-------+
# |              userSK|source_user_id|         source_name|         source_city|source_zipcode|          scd_start|            scd_end|          source_md5|current|
# +--------------------+--------------+--------------------+--------------------+--------------+-------------------+-------------------+--------------------+-------+
# |73cac594-54c6-4c9...|             1|         Bouman Lars|           Antwerpen|          2060|1999-01-01 00:00:00|2100-12-12 00:00:00|976f30b5dd22c74bb...|   true|
# |a2e2c171-d426-4f6...|             2|   van der Zee Julia| Wilrijk (Antwerpen)|          2610|1999-01-01 00:00:00|2100-12-12 00:00:00|c34f85e721c0459e3...|   true|
# |0cf8b315-a89e-44b...|             3|     de Boer Ricardo|           Wommelgem|          2160|1999-01-01 00:00:00|2100-12-12 00:00:00|7b8896e6b68fdbcd6...|   true|
# |f6b22ebe-5b5f-4bf...|             4|      Willems Angela|             Schoten|          2900|1999-01-01 00:00:00|2100-12-12 00:00:00|e4c3d29a22d12881e...|   true|
# |fe5ebe66-8f5a-49f...|             5|    Heijnen Patricia|                Hove|          2540|1999-01-01 00:00:00|2100-12-12 00:00:00|1c98c7af02e00fd83...|   true|
# |1059109b-79b3-4ab...|             6|      Driessen Anouk|              Edegem|          2650|1999-01-01 00:00:00|2100-12-12 00:00:00|7ec6f63578edcbfb9...|   true|
# |97af2127-22c5-4bd...|             7|      Dijkstra Frank|             Schoten|          2900|1999-01-01 00:00:00|2100-12-12 00:00:00|7f9b5868a2342a0b4...|   true|
# |5a97fb75-dce3-447...|             8|  den Hartog Suzanne| Merksem (Antwerpen)|          2170|1999-01-01 00:00:00|2100-12-12 00:00:00|70444d96a204dd6a3...|   true|
# |64b4e8ba-5524-4cd...|             9|            Smit Tim| Berchem (Antwerpen)|          2600|1999-01-01 00:00:00|2100-12-12 00:00:00|4cda5391c27cea8c9...|   true|
# |a134b0c8-8236-4ef...|            10|van der Steen Carmen|           Antwerpen|          2020|1999-01-01 00:00:00|2100-12-12 00:00:00|596a7838e7158e59b...|   true|
# |0dbbca80-eeda-47b...|            11| de Ruijter Daniëlle|  Burcht/Zwijndrecht|          2070|1999-01-01 00:00:00|2100-12-12 00:00:00|f4d1dfe411a80f792...|   true|
# |8c9c4278-7838-48b...|            12|        Simons Thijs|Antwerpen/Berendr...|          2040|1999-01-01 00:00:00|2100-12-12 00:00:00|b6768e0e009a760c2...|   true|
# |feeb81e7-72ec-489...|            13|          Groen Rens| Merksem (Antwerpen)|          2170|1999-01-01 00:00:00|2100-12-12 00:00:00|03b998705111e0d9f...|   true|
# |85c068e0-161f-4da...|            14|   van der Veer Romy|    Kontich/Waarloos|          2550|1999-01-01 00:00:00|2100-12-12 00:00:00|446430c5955dd65ed...|   true|
# |c92c0cfd-1010-42d...|            15|           Hoek Emma|Broechem/Emblem/O...|          2520|1999-01-01 00:00:00|2100-12-12 00:00:00|4871f5a77290e2c5f...|   true|
